# %% [markdown]
# # MindVault - Kaggle Cloud Backend Setup
# Run this notebook in Kaggle if your local machine cannot run Llama 3 efficiently. This will spin up Ollama on Kaggle's powerful GPUs and expose it via Ngrok so your local MindVault app can connect to it.

# %%
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
import os
import subprocess
import time

# Start Ollama server in background
subprocess.Popen(["ollama", "serve"])
time.sleep(5)

# Pull Llama 3.1
# !ollama pull llama3.1

# %%
# !pip install pyngrok
from pyngrok import ngrok

# Put your ngrok authtoken here
ngrok.set_auth_token("YOUR_NGROK_AUTHTOKEN_HERE")

public_url = ngrok.connect(11434).public_url
print(f"\n\n>>> YOUR CLOUD LLM ENDPOINT: {public_url} <<<\n\n")
print("Copy this URL and paste it into the Cloud Endpoint input box in the MindVault UI.")
